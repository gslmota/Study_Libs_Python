# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_excel("/home/gabas/Downloads/drive-download-20230112T000149Z-001/Aula 1/Exportar/Vendas - Dez.xlsx",index_col=0, parse_dates=True)

# %%
dados.head()
# Out:
#                    Data             ID Loja          Produto  Quantidade  \
# Código Venda
# 65014        2019-12-01    Shopping Morumbi   Sunga Listrado           5
# 65014        2019-12-01    Shopping Morumbi  Casaco Listrado           1
# 65016        2019-12-01   Iguatemi Campinas  Sapato Listrado           2
# 65016        2019-12-01   Iguatemi Campinas           Casaco           1
# 65017        2019-12-01  Shopping SP Market       Gorro Liso           3
#
#               Valor Unitário  Valor Final
# Código Venda
# 65014                    114          570
# 65014                    269          269
# 65016                    363          726
# 65016                    250          250
# 65017                     92          276

# %%
dados.describe()
# Out:
#         Quantidade  Valor Unitário  Valor Final
# count  7089.000000     7089.000000  7089.000000
# mean      2.147976      193.651150   411.526449
# std       1.244048      148.023448   424.007114
# min       1.000000       30.000000    30.000000
# 25%       1.000000      100.000000   160.000000
# 50%       2.000000      150.000000   269.000000
# 75%       3.000000      248.000000   524.000000
# max       5.000000      750.000000  3750.000000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7089 entries, 65014 to 69997
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Data            7089 non-null   datetime64[ns]
#  1   ID Loja         7089 non-null   object
#  2   Produto         7089 non-null   object
#  3   Quantidade      7089 non-null   int64
#  4   Valor Unitário  7089 non-null   int64
#  5   Valor Final     7089 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 387.7+ KB

# %%
dados["Data"]
# Out:
# Código Venda
# 65014   2019-12-01
# 65014   2019-12-01
# 65016   2019-12-01
# 65016   2019-12-01
# 65017   2019-12-01
#            ...
# 69996   2019-12-26
# 69996   2019-12-26
# 69996   2019-12-26
# 69997   2019-12-26
# 69997   2019-12-26
# Name: Data, Length: 7089, dtype: datetime64[ns]

# %%
dados[["Produto","ID Loja"]]
# Out:
#                        Produto                     ID Loja
# Código Venda
# 65014           Sunga Listrado            Shopping Morumbi
# 65014          Casaco Listrado            Shopping Morumbi
# 65016          Sapato Listrado           Iguatemi Campinas
# 65016                   Casaco           Iguatemi Campinas
# 65017               Gorro Liso          Shopping SP Market
# ...                        ...                         ...
# 69996           Short Listrado  Center Shopping Uberlândia
# 69996                  Mochila  Center Shopping Uberlândia
# 69996         Pulseira Estampa  Center Shopping Uberlândia
# 69997          Camisa Listrado           Ribeirão Shopping
# 69997              Short Linho           Ribeirão Shopping
#
# [7089 rows x 2 columns]

# %%
dados[dados["Quantidade"] > 4]
# Out:
#       Código Venda       Data                           ID Loja  \
# 0            65014 2019-12-01                  Shopping Morumbi
# 11           65020 2019-12-01                  Shopping Morumbi
# 14           65025 2019-12-01               Shopping Ibirapuera
# 18           65028 2019-12-01                 Iguatemi Campinas
# 27           65034 2019-12-01               Shopping Vila Velha
# ...            ...        ...                               ...
# 7010         69944 2019-12-25                Iguatemi Esplanada
# 7017         69953 2019-12-25               Bourbon Shopping SP
# 7047         69968 2019-12-25       Shopping Iguatemi Fortaleza
# 7054         69972 2019-12-26                 Salvador Shopping
# 7056         69975 2019-12-26  Shopping Center Leste Aricanduva
#
#               Produto  Quantidade  Valor Unitário  Valor Final
# 0      Sunga Listrado           5             114          570
# 11    Camiseta Xadrez           5             200         1000
# ...

# %%
# codigo do produto
dados.loc[dados["Quantidade"] > 4, "Código Venda"]
# Out:
# 0       65014
# 11      65020
# 14      65025
# 18      65028
# 27      65034
#         ...
# 7010    69944
# 7017    69953
# 7047    69968
# 7054    69972
# 7056    69975
# Name: Código Venda, Length: 536, dtype: int64

# %%
dados.plot()
plt.show()

# %%
dados.plot(subplots=True)
plt.show()
